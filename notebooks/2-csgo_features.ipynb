# %%
import pandas as pd
import numpy as np
import pickle
from itertools import compress

# %%
with open('../data/csgo_df.pkl', 'rb') as f:
    df_raw = pickle.load(f)

# %%
player_count = pd.read_csv('../data/csgo.csv')

# %%
df = df_raw.copy()

# %% [markdown]
# ### Fill missing days with 0s for every item

# %% [markdown]
# #### List of items:

# %%
items = df.item_name.unique()

# %% [markdown]
# #### Possible parentheticals:

# %%
parentheticals = set([item[item.rfind('('):] for item in items if item.find('(') >= 0])
parentheticals
# Out:
# {'(Battle Green)',
#  '(Battle-Scarred)',
#  '(Bazooka Pink)',
#  '(Blood Red)',
#  '(Blue)',
#  '(Brick Red)',
#  '(Cash Green)',
#  '(Desert Amber)',
#  '(Dust Brown)',
#  '(Factory New)',
#  '(Field-Tested)',
#  '(Foil)',
#  '(Foil)  | MLG Columbus 2016',
#  '(Foil) | Atlanta 2017',
#  '(Foil) | Boston 2018',
#  '(Foil) | Cluj-Napoca 2015',
#  '(Foil) | Cologne 2015',
#  '(Foil) | Cologne 2016',
#  '(Foil) | DreamHack 2014',
#  '(Foil) | Katowice 2014',
#  '(Foil) | Katowice 2015',
#  '(Foil) | Krakow 2017',
#  '(Foil) | MLG Columbus 2016',
#  '(Frog Green)',
#  '(Gold) | Boston 2018',
#  '(Gold) | Krakow 2017',
#  '(Holo)',
#  '(Holo) | Atlanta 2017',
#  '(Holo) | Boston 2018',
#  '(Holo) | Cologne 2014',
#  '(Holo) | Cologne 2016',
#  '(Holo) | DreamHack 2014',
#  '(Holo) | Katowice 2014',
#  '(Holo) | Katowice 2015',
#  '(Holo) | Krakow 2017',
#  '(Holo) | MLG Columbus 2016',
#  '(Holo-Foil)',
#  '(Jungle Green)',
#  '(Minimal Wear)',
#  '(Monarch Blue)',
#  '(Monster Purple)',
#  '(Princess Pink)',
#  '(Red)',
#  '(SWAT Blue)',
#  '(Shark White)',
#  '(Tiger Orange)',
#  '(Tracer Yellow)',
#  '(Violent Violet)',
#  '(War Pig Pink)',
#  '(Well-Worn)',
#  '(Wire Blue)'}

# %% [markdown]
# #### We have colors, quality, foil, events (after '|', and likely separate of parentheticals if foil is missing)

# %% [markdown]
# #### Compress is like masking for lists

# %%
list(compress(items, ['(Foil)  | MLG Columbus 2016' in item for item in items]))
# Out:
# ['Sticker | AdreN (Foil)  | MLG Columbus 2016']

# %%
'Sticker | AdreN (Foil) | MLG Columbus 2016'
# Out:
# 'Sticker | AdreN (Foil) | MLG Columbus 2016'

# %%
df = df.replace(to_replace='Sticker | AdreN (Foil)  | MLG Columbus 2016', value='Sticker | AdreN (Foil) | MLG Columbus 2016')

# %% [markdown]
# #### Removed the extra space in that string

# %% [markdown]
# #### Looking at the items without parentheses

# %%
df['parenthetical'] = [item.find('(') >= 0 for item in df.item_name]

# %%
len(df[~df.parenthetical].item_name.unique())
# Out:
# 1450

# %% [markdown]
# 1450 unique items left to categorize

# %%
df.head()
# Out:
#    app          date                           item_name  median_sell_price  \
# 0  730  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  730  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  730  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  730  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  730  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity    release_date  parenthetical
# 0       135  18 August 2016           True
# 1       166  18 August 2016           True
# 2       142  18 August 2016           True
# 3        98  18 August 2016           True
# 4       125  18 August 2016           True

# %%
gun_list = ['AK-47',
 'AUG',
 'AWP',
 'CZ75-Auto',
 'Desert Eagle',
 'Dual Berettas',
 'FAMAS',
 'Five-SeveN',
 'G3SG1',
 'Galil AR',
 'Glock-18',
 'M249',
 'M4A1-S',
 'M4A4',
 'MAC-10',
 'MAG-7',
 'MP7',
 'MP9',
 'Negev',
 'Nova',
 'P2000',
 'P250',
 'P90',
 'PP-Bizon',
 'R8 Revolver',
 'SCAR-20',
 'SG 553',
 'SSG 08',
 'Sawed-Off',
 'Tec-9',
 'UMP-45',
 'USP-S',
 'XM1014']

# %% [markdown]
# #### Add guns column

# %%
df['gun_bool'] = [any([x in y for x in gun_list]) for y in df.item_name]

# %%
sorted(set([x.split('|')[0][:-1] for x in df[df.gun_bool].item_name.unique()]))
# Out:
# ['AK-47',
#  'AUG',
#  'AWP',
#  'CZ75-Auto',
#  'Desert Eagle',
#  'Dual Berettas',
#  'FAMAS',
#  'Five-SeveN',
#  'G3SG1',
#  'Galil AR',
#  'Glock-18',
#  'M249',
#  'M4A1-S',
#  'M4A4',
#  'MAC-10',
#  'MAG-7',
#  'MP7',
#  'MP9',
#  'Negev',
#  'Nova',
#  'P2000',
#  'P250',
#  'P90',
#  'PP-Bizon',
#  'R8 Revolver',
#  'SCAR-20',
#  'SG 553',
#  'SSG 08',
#  'Sawed-Off',
#  'Souvenir AK-47',
#  'Souvenir AUG',
#  'Souvenir AWP',
#  'Souvenir CZ75-Auto',
#  'Souvenir Desert Eagle',
#  'Souvenir Dual Berettas',
#  'Souvenir FAMAS',
#  'Souvenir Five-SeveN',
#  'Souvenir G3SG1',
#  'Souvenir Galil AR',
#  'Souvenir Glock-18',
#  'Souvenir M249',
#  'Souvenir M4A1-S',
#  'Souvenir M4A4',
#  'Souvenir MAC-10',
#  'Souvenir MAG-7',
#  'Souvenir MP7',
#  'Souvenir MP9',
#  'Souvenir Negev',
#  'Souvenir Nova',
#  'Souvenir P2000',
#  'Souvenir P250',
#  'Souvenir P90',
#  'Souvenir PP-Bizon',
#  'Souvenir R8 Revolver',
#  'Souvenir SCAR-20',
#  'Souvenir SG 553',
#  'Souvenir SSG 08',
#  'Souvenir Sawed-Off',
#  'Souvenir Tec-9',
#  'Souvenir UMP-45',
#  'Souvenir USP-S',
#  'Souvenir XM1014',
#  'StatTrak™ AK-47',
#  'StatTrak™ AUG',
#  'StatTrak™ AWP',
#  'StatTrak™ CZ75-Auto',
#  'StatTrak™ Desert Eagle',
#  'StatTrak™ Dual Berettas',
#  'StatTrak™ FAMAS',
#  'StatTrak™ Five-SeveN',
#  'StatTrak™ G3SG1',
#  'StatTrak™ Galil AR',
#  'StatTrak™ Glock-18',
#  'StatTrak™ M249',
#  'StatTrak™ M4A1-S',
#  'StatTrak™ M4A4',
#  'StatTrak™ MAC-10',
#  'StatTrak™ MAG-7',
#  'StatTrak™ MP7',
#  'StatTrak™ MP9',
#  'StatTrak™ Negev',
#  'StatTrak™ Nova',
#  'StatTrak™ P2000',
#  'StatTrak™ P250',
#  'StatTrak™ P90',
#  'StatTrak™ PP-Bizon',
#  'StatTrak™ R8 Revolver',
#  'StatTrak™ SCAR-20',
#  'StatTrak™ SG 553',
#  'StatTrak™ SSG 08',
#  'StatTrak™ Sawed-Off',
#  'StatTrak™ Tec-9',
#  'StatTrak™ UMP-45',
#  'StatTrak™ USP-S',
#  'StatTrak™ XM1014',
#  'Tec-9',
#  'UMP-45',
#  'USP-S',
#  'XM1014']

# %% [markdown]
# #### Separate StatTraks and Souvenirs

# %%
df['StatTrak'] = [x.find('Stat') == 0 for x in df.item_name]

# %%
df.loc[df.StatTrak, 'item_name'] = [x.split('StatTrak™ ')[1] for x in df.loc[df.StatTrak, 'item_name']]

# %%
df[df.StatTrak].head()
# Out:
#       app          date                  item_name  median_sell_price  \
# 8629  730  1.471583e+09  P90 | Grim (Field-Tested)              7.559
# 8630  730  1.471669e+09  P90 | Grim (Field-Tested)              5.642
# 8631  730  1.471756e+09  P90 | Grim (Field-Tested)              4.711
# 8632  730  1.471842e+09  P90 | Grim (Field-Tested)              4.308
# 8633  730  1.471928e+09  P90 | Grim (Field-Tested)              3.919
#
#       quantity    release_date  parenthetical  gun_bool  StatTrak
# 8629       153  18 August 2016           True      True      True
# 8630       179  18 August 2016           True      True      True
# 8631       150  18 August 2016           True      True      True
# 8632       140  18 August 2016           True      True      True
# 8633       138  18 August 2016           True      True      True

# %% [markdown]
# #### Separate Souvenir

# %%
df['souvenir'] = [x.find('Souv') == 0 for x in df.item_name]

# %%
df.loc[df.souvenir, 'item_name'] = [x.split('Souvenir ')[1] for x in df.loc[df.souvenir, 'item_name']]

# %%
df[df.souvenir].head()
# Out:
#         app          date                             item_name  \
# 195393  730  1.416722e+09  P250 | Nuclear Threat (Minimal Wear)
# 195394  730  1.419746e+09  P250 | Nuclear Threat (Minimal Wear)
# 195395  730  1.420178e+09  P250 | Nuclear Threat (Minimal Wear)
# 195396  730  1.421993e+09  P250 | Nuclear Threat (Minimal Wear)
# 195397  730  1.426396e+09  P250 | Nuclear Threat (Minimal Wear)
#
#         median_sell_price  quantity    release_date  parenthetical  gun_bool  \
# 195393            234.660         1  14 August 2013           True      True
# 195394            399.996         1  14 August 2013           True      True
# 195395            399.996         1  14 August 2013           True      True
# 195396            302.380         1  14 August 2013           True      True
# 195397            139.219         2  14 August 2013           True      True
#
#         StatTrak  souvenir
# 195393     False      True
# 195394     False      True
# 195395     False      True
# 195396     False      True
# 195397     False      True

# %% [markdown]
# #### Separate Gun, Skin, quality

# %%
df.loc[799720].date
# Out:
# 1513922400.0

# %%
df['gun_type'], df['skin'], df['quality'] = np.nan, np.nan, np.nan

# %%
df.head()
# Out:
#    app          date                           item_name  median_sell_price  \
# 0  730  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  730  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  730  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  730  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  730  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity    release_date  parenthetical  gun_bool  StatTrak  souvenir  \
# 0       135  18 August 2016           True      True     False     False
# 1       166  18 August 2016           True      True     False     False
# 2       142  18 August 2016           True      True     False     False
# 3        98  18 August 2016           True      True     False     False
# 4       125  18 August 2016           True      True     False     False
#
#    gun_type  skin  quality
# 0       NaN   NaN      NaN
# 1       NaN   NaN      NaN
# 2       NaN   NaN      NaN
# 3       NaN   NaN      NaN
# 4       NaN   NaN      NaN

# %%
df.loc[df.gun_bool, 'gun_type'] = [x.split(' |')[0] for x in df.item_name[df.gun_bool]]

# %%
df.loc[df.gun_bool, 'skin'] = [x.split('| ')[1][:x.split('| ')[1].rfind('(')] for x in df.item_name[df.gun_bool]]

# %%
df.loc[df.gun_bool, 'quality'] = [x.split('(')[-1][:-1] for x in df.item_name[df.gun_bool]]

# %%
df.head()
# Out:
#    app          date                           item_name  median_sell_price  \
# 0  730  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  730  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  730  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  730  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  730  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity    release_date  parenthetical  gun_bool  StatTrak  souvenir  \
# 0       135  18 August 2016           True      True     False     False
# 1       166  18 August 2016           True      True     False     False
# 2       142  18 August 2016           True      True     False     False
# 3        98  18 August 2016           True      True     False     False
# 4       125  18 August 2016           True      True     False     False
#
#    gun_type     skin         quality
# 0  Glock-18  Weasel   Battle-Scarred
# 1  Glock-18  Weasel   Battle-Scarred
# 2  Glock-18  Weasel   Battle-Scarred
# 3  Glock-18  Weasel   Battle-Scarred
# 4  Glock-18  Weasel   Battle-Scarred

# %% [markdown]
# #### Keys

# %%
df['keys'] = [x.find('Key') > -1 for x in df.item_name]

# %% [markdown]
# #### Capsules

# %%
df['capsules'] = [(x.find('Capsule') > -1) and not y for x, y in zip(df.item_name, df['keys'])]

# %% [markdown]
# #### Stickers

# %%
df['stickers'] = [(x.find('Sticker') >= 0) and not y and not z for x, y, z in zip(df.item_name, df['keys'], df['capsules'])]

# %%
df.head()
# Out:
#    app          date                           item_name  median_sell_price  \
# 0  730  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  730  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  730  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  730  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  730  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity    release_date  parenthetical  gun_bool  StatTrak  souvenir  \
# 0       135  18 August 2016           True      True     False     False
# 1       166  18 August 2016           True      True     False     False
# 2       142  18 August 2016           True      True     False     False
# 3        98  18 August 2016           True      True     False     False
# 4       125  18 August 2016           True      True     False     False
#
#    gun_type     skin         quality   keys  capsules  stickers
# 0  Glock-18  Weasel   Battle-Scarred  False     False     False
# 1  Glock-18  Weasel   Battle-Scarred  False     False     False
# 2  Glock-18  Weasel   Battle-Scarred  False     False     False
# 3  Glock-18  Weasel   Battle-Scarred  False     False     False
# 4  Glock-18  Weasel   Battle-Scarred  False     False     False

# %% [markdown]
# #### Tournaments

# %%
tournaments = ['2018 ELEAGUE Boston',
'2017 PGL Krakow',
'2015 ESL One Cologne', 
'2017 ELEAGUE Atlanta',
'2016 MLG Columbus',
'2016 ESL One Cologne',
'2015 DreamHack Cluj-Napoca', 
'2015 ESL One Katowice',
'2014 ESL One Cologne',
'2014 EMS One Katowice',
'2014 DreamHack Winter',
'2013 DreamHack Winter']

# %%
tournaments = [x[5:] + ' ' + x[0:4] for x in tournaments]

# %%
tournaments
# Out:
# ['ELEAGUE Boston 2018',
#  'PGL Krakow 2017',
#  'ESL One Cologne 2015',
#  'ELEAGUE Atlanta 2017',
#  'MLG Columbus 2016',
#  'ESL One Cologne 2016',
#  'DreamHack Cluj-Napoca 2015',
#  'ESL One Katowice 2015',
#  'ESL One Cologne 2014',
#  'EMS One Katowice 2014',
#  'DreamHack Winter 2014',
#  'DreamHack Winter 2013']

# %%
df['event_item'] = [any([x in y for x in tournaments]) for y in df.item_name]

# %%
set([x[x.rfind('|')+1:] for x in df[df['event_item']].item_name])
# Out:
# {' DreamHack Winter 2014',
#  ' DreamHack Winter 2014 (Foil)',
#  ' ESL One Cologne 2014 (Blue)',
#  ' ESL One Cologne 2014 (Red)',
#  ' MLG Columbus 2016',
#  'DreamHack Cluj-Napoca 2015 Cache Souvenir Package',
#  'DreamHack Cluj-Napoca 2015 Challengers (Foil)',
#  'DreamHack Cluj-Napoca 2015 Cobblestone Souvenir Package',
#  'DreamHack Cluj-Napoca 2015 Dust II Souvenir Package',
#  'DreamHack Cluj-Napoca 2015 Inferno Souvenir Package',
#  'DreamHack Cluj-Napoca 2015 Legends (Foil)',
#  'DreamHack Cluj-Napoca 2015 Mirage Souvenir Package',
#  'DreamHack Cluj-Napoca 2015 Overpass Souvenir Package',
#  'DreamHack Cluj-Napoca 2015 Train Souvenir Package',
#  'ESL One Cologne 2014 Cache Souvenir Package',
#  'ESL One Cologne 2014 Challengers',
#  'ESL One Cologne 2014 Cobblestone Souvenir Package',
#  'ESL One Cologne 2014 Dust II Souvenir Package',
#  'ESL One Cologne 2014 Inferno Souvenir Package',
#  'ESL One Cologne 2014 Legends',
#  'ESL One Cologne 2014 Mirage Souvenir Package',
#  'ESL One Cologne 2014 Nuke Souvenir Package',
#  'ESL One Cologne 2014 Overpass Souvenir Package',
#  'ESL One Cologne 2015 Cache Souvenir Package',
#  'ESL One Cologne 2015 Challengers (Foil)',
#  'ESL One Cologne 2015 Cobblestone Souvenir Package',
#  'ESL One Cologne 2015 Dust II Souvenir Package',
#  'ESL One Cologne 2015 Inferno Souvenir Package',
#  'ESL One Cologne 2015 Legends (Foil)',
#  'ESL One Cologne 2015 Mirage Souvenir Package',
#  'ESL One Cologne 2015 Overpass Souvenir Package',
#  'ESL One Cologne 2015 Train Souvenir Package',
#  'ESL One Katowice 2015 Cache Souvenir Package',
#  'ESL One Katowice 2015 Challengers (Holo-Foil)',
#  'ESL One Katowice 2015 Cobblestone Souvenir Package',
#  'ESL One Katowice 2015 Dust II Souvenir Package',
#  'ESL One Katowice 2015 Inferno Souvenir Package',
#  'ESL One Katowice 2015 Legends (Holo-Foil)',
#  'ESL One Katowice 2015 Mirage Souvenir Package',
#  'ESL One Katowice 2015 Nuke Souvenir Package',
#  'ESL One Katowice 2015 Overpass Souvenir Package',
#  'MLG Columbus 2016 Cache Souvenir Package',
#  'MLG Columbus 2016 Challengers (Holo-Foil)',
#  'MLG Columbus 2016 Cobblestone Souvenir Package',
#  'MLG Columbus 2016 Dust II Souvenir Package',
#  'MLG Columbus 2016 Inferno Souvenir Package',
#  'MLG Columbus 2016 Legends (Holo-Foil)',
#  'MLG Columbus 2016 Mirage Souvenir Package',
#  'MLG Columbus 2016 Nuke Souvenir Package',
#  'MLG Columbus 2016 Overpass Souvenir Package',
#  'MLG Columbus 2016 Train Souvenir Package'}

# %%
df[df['event_item']].item_name.iloc[100000][df[df['event_item']].item_name.iloc[100000].rfind('|'):]
# Out:
# 'e'

# %%
df[df['event_item']].item_name.iloc[100000]
# Out:
# 'ESL One Katowice 2015 Overpass Souvenir Package'

# %% [markdown]
# #### Let's leave everything else as 'Other' for now

# %% [markdown]
# #### Add player counts

# %%
df_player = pd.read_csv('../data/csgo.csv')

# %% [markdown]
# #### Add release dates

# %%
from pymongo import MongoClient
client = MongoClient()
db = client['steam_capstone']
collection = db['item_release_dates']

# %%
releases = list(collection.find())

# %%
# for entry in releases:
#     for item in entry['items']:
#         mask = [item + ' (' in x for x in csdf['item_name']]
#         csdf.loc[mask, 'release_date'] = entry['release_date']

# %% [markdown]
# #### Add readable and epoch date for each date feature

# %% [markdown]
# #### Put item_name back together

# %%
df.loc[:,'item_name'] = df_raw['item_name']
df = df.reset_index(drop=True)

# %% [markdown]
# #### Add days since release for time shifting

# %%
df['days_since_release'] = np.nan
df['days_since_release'] = df.groupby('item_name').transform(lambda x: np.arange(len(x)))

# %%
df.head()
# Out:
#    index  app          date                           item_name  \
# 0      0  730  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)
# 1      1  730  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)
# 2      2  730  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)
# 3      3  730  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)
# 4      4  730  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)
#
#    median_sell_price  quantity    release_date  parenthetical  gun_bool  \
# 0              6.193       135  18 August 2016           True      True
# 1              5.103       166  18 August 2016           True      True
# 2              4.721       142  18 August 2016           True      True
# 3              4.302        98  18 August 2016           True      True
# 4              3.898       125  18 August 2016           True      True
#
#    StatTrak  souvenir  gun_type     skin         quality   keys  capsules  \
# 0     False     False  Glock-18  Weasel   Battle-Scarred  False     False
# 1     False     False  Glock-18  Weasel   Battle-Scarred  False     False
# 2     False     False  Glock-18  Weasel   Battle-Scarred  False     False
# 3     False     False  Glock-18  Weasel   Battle-Scarred  False     False
# 4     False     False  Glock-18  Weasel   Battle-Scarred  False     False
#
#    stickers  event_item  days_since_release
# 0     False       False                   0
# 1     False       False                   1
# 2     False       False                   2
# 3     False       False                   3
# 4     False       False                   4

# %%
with open('../data/csgo_features.pkl', 'wb') as f:
    pickle.dump(df, f)

# %% [markdown]
# #### Now I need scripts to remove items that sell for $0.03 and have low quantity

# %% [markdown]
# # Moving everything over from 'simple_csgo_df.ipynb'

# %%
import pickle
import pandas as pd
import numpy as np
import datetime
import time

# %%
with open('../data/csgo_df.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
df.head()
# Out:
#    app          date                           item_name  median_sell_price  \
# 0  730  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  730  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  730  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  730  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  730  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity    release_date
# 0       135  18 August 2016
# 1       166  18 August 2016
# 2       142  18 August 2016
# 3        98  18 August 2016
# 4       125  18 August 2016

# %%
df = df.drop(columns=['app', 'release_date'])

# %%
df['days_since_release'] = np.nan
df['days_since_release'] = df.groupby('item_name').transform(lambda x: np.arange(len(x)))

# %%
df['est_release'] = df.groupby('item_name')['date'].transform('min')

# %%
df.head()
# Out:
#            date                           item_name  median_sell_price  \
# 0  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity  days_since_release   est_release
# 0       135                   0  1.471583e+09
# 1       166                   1  1.471583e+09
# 2       142                   2  1.471583e+09
# 3        98                   3  1.471583e+09
# 4       125                   4  1.471583e+09

# %%
with open('../data/cs_df_S.pkl', 'wb') as f:
    pickle.dump(df, f)

# %%
with open('../data/csgo_features.pkl', 'rb') as f:    
    df_medium = pickle.load(f)

# %%
df_medium.head()
# Out:
#    app          date                           item_name  median_sell_price  \
# 0  730  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  730  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  730  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  730  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  730  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity    release_date  parenthetical  gun_bool  StatTrak  souvenir  \
# 0       135  18 August 2016           True      True     False     False
# 1       166  18 August 2016           True      True     False     False
# 2       142  18 August 2016           True      True     False     False
# 3        98  18 August 2016           True      True     False     False
# 4       125  18 August 2016           True      True     False     False
#
#    gun_type     skin         quality   keys  capsules  stickers  event_item  \
# 0  Glock-18  Weasel   Battle-Scarred  False     False     False       False
# 1  Glock-18  Weasel   Battle-Scarred  False     False     False       False
# 2  Glock-18  Weasel   Battle-Scarred  False     False     False       False
# 3  Glock-18  Weasel   Battle-Scarred  False     False     False       False
# 4  Glock-18  Weasel   Battle-Scarred  False     False     False       False
#
#    days_since_release
# 0                   0
# 1                   1
# 2                   2
# 3                   3
# 4                   4

# %%
df_medium = df_medium.drop(columns=['app', 'release_date', 'parenthetical', 'event_item'])

# %%
df_medium.head()
# Out:
#            date                           item_name  median_sell_price  \
# 0  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity  gun_bool  StatTrak  souvenir  gun_type     skin         quality  \
# 0       135      True     False     False  Glock-18  Weasel   Battle-Scarred
# 1       166      True     False     False  Glock-18  Weasel   Battle-Scarred
# 2       142      True     False     False  Glock-18  Weasel   Battle-Scarred
# 3        98      True     False     False  Glock-18  Weasel   Battle-Scarred
# 4       125      True     False     False  Glock-18  Weasel   Battle-Scarred
#
#     keys  capsules  stickers  days_since_release
# 0  False     False     False                   0
# 1  False     False     False                   1
# 2  False     False     False                   2
# 3  False     False     False                   3
# 4  False     False     False                   4

# %%
df_medium['est_release'] = df_medium.groupby('item_name')['date'].transform('min')

# %%
df_medium.head()
# Out:
#            date                           item_name  median_sell_price  \
# 0  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity  gun_bool  StatTrak  souvenir  gun_type     skin         quality  \
# 0       135      True     False     False  Glock-18  Weasel   Battle-Scarred
# 1       166      True     False     False  Glock-18  Weasel   Battle-Scarred
# 2       142      True     False     False  Glock-18  Weasel   Battle-Scarred
# 3        98      True     False     False  Glock-18  Weasel   Battle-Scarred
# 4       125      True     False     False  Glock-18  Weasel   Battle-Scarred
#
#     keys  capsules  stickers  days_since_release   est_release
# 0  False     False     False                   0  1.471583e+09
# 1  False     False     False                   1  1.471583e+09
# 2  False     False     False                   2  1.471583e+09
# 3  False     False     False                   3  1.471583e+09
# 4  False     False     False                   4  1.471583e+09

# %%
df_medium['date_str'] = [datetime.datetime.fromtimestamp(t).strftime('%d %b %Y') for t in df_medium.date]
df_medium['est_release_str'] = [datetime.datetime.fromtimestamp(t).strftime('%d %b %Y') for t in df_medium.est_release]

# %%
df_medium.head()
# Out:
#            date                           item_name  median_sell_price  \
# 0  1.471583e+09  Glock-18 | Weasel (Battle-Scarred)              6.193
# 1  1.471669e+09  Glock-18 | Weasel (Battle-Scarred)              5.103
# 2  1.471756e+09  Glock-18 | Weasel (Battle-Scarred)              4.721
# 3  1.471842e+09  Glock-18 | Weasel (Battle-Scarred)              4.302
# 4  1.471928e+09  Glock-18 | Weasel (Battle-Scarred)              3.898
#
#    quantity  gun_bool  StatTrak  souvenir  gun_type     skin         quality  \
# 0       135      True     False     False  Glock-18  Weasel   Battle-Scarred
# 1       166      True     False     False  Glock-18  Weasel   Battle-Scarred
# 2       142      True     False     False  Glock-18  Weasel   Battle-Scarred
# 3        98      True     False     False  Glock-18  Weasel   Battle-Scarred
# 4       125      True     False     False  Glock-18  Weasel   Battle-Scarred
#
#     keys  capsules  stickers  days_since_release   est_release     date_str  \
# 0  False     False     False                   0  1.471583e+09  19 Aug 2016
# 1  False     False     False                   1  1.471583e+09  20 Aug 2016
# 2  False     False     False                   2  1.471583e+09  21 Aug 2016
# 3  False     False     False                   3  1.471583e+09  22 Aug 2016
# 4  False     False     False                   4  1.471583e+09  23 Aug 2016
#
#   est_release_str
# 0     19 Aug 2016
# 1     19 Aug 2016
# 2     19 Aug 2016
# 3     19 Aug 2016
# 4     19 Aug 2016

# %%
df_medium.columns
# Out:
# Index(['date', 'item_name', 'median_sell_price', 'quantity', 'gun_bool',
#        'StatTrak', 'souvenir', 'gun_type', 'skin', 'quality', 'keys',
#        'capsules', 'stickers', 'days_since_release', 'est_release', 'date_str',
#        'est_release_str'],
#       dtype='object')

# %%
cols = ['item_name', 'date_str', 'median_sell_price', 'quantity', 'est_release_str',
        'days_since_release', 'gun_type', 'skin', 'quality', 'gun_bool', 'StatTrak',
        'souvenir', 'keys', 'capsules', 'stickers', 'date', 'est_release']

# %%
df_medium = df_medium[cols]

# %%
df_medium['timestamp'] = [np.datetime64(datetime.datetime.fromtimestamp(t).date()) for t in df_medium.date]

# %%
with open('../data/cs_df_M.pkl', 'wb') as f:
    pickle.dump(df_medium, f)

# %%
np.datetime64(datetime.datetime.fromtimestamp(1.471842e+09).date())
# Out:
# numpy.datetime64('2016-08-22')
